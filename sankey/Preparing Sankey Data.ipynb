# %%
import pandas as pd
import json

# %%
df = pd.read_csv('data/Payments to US Entities Working - Entities - Clean.csv')

# %%
df.head()
# Out:
#                       Entity Name           Reporting Company Payment Type  \
# 0                 State of Alaska  Agnico Eagle Mines Limited         Fees
# 1        United States Government  Agnico Eagle Mines Limited         Fees
# 2   Arizona Department of Revenue                 Agrium Inc.        Taxes
# 3             State of California                 Agrium Inc.        Taxes
# 4  Colorado Department of Revenue                 Agrium Inc.        Taxes
#
#    Start Date    End Date Federal Government Tribal Governments  \
# 0  01-01-2016  12-31-2016                  N                NaN
# 1  01-01-2016  12-31-2016                  Y                NaN
# 2  01-01-2016  12-31-2016                  N                NaN
# 3  01-01-2016  12-31-2016                  N                NaN
# 4  01-01-2016  12-31-2016                  N                NaN
#
#                   State  Value (USD)  \
# 0                Alaska      75448.0
# 1  District of Columbia     377244.0
# 2               Arizona     347065.0
# 3            California    6224537.0
# 4              Colorado     347065.0
#
#                                                Notes Unnamed: 10
# 0                    Department of Natural Resources         NaN
# 1                          Bureau of Land Management         NaN
# 2  State taxes paid - $348K USD translated at an ...         NaN
# 3  State taxes paid - $6.19M USD translated at an...         NaN
# 4  State taxes paid - $343K USD translated at an ...         NaN

# %%
df["Government Type"] = "State"
df.loc[df["Tribal Governments"].notnull(),"Government Type"] = "Tribal"
df.loc[df["Federal Government"] == "Y","Government Type"] = "Federal"
df.loc[df["State"].isnull(),"Government Type"] = "Unknown"

# %%
df.loc[df["State"].isnull()]
# Out:
#                                            Entity Name  \
# 52                                    Various counties
# 247                          County Recorder (Various)
# 248                       Secretary of State (Various)
# 365                   COMMISSIONER OF THE GENERAL LAND
# 366                  DIRECTOR, DIVISION OF OIL AND GAS
# 380                State Emergency Response Commission
# 442                                                NaN
# 443                                                NaN
# 444  Note: Removed any company w/ fiscal year endin...
#
#           Reporting Company Payment Type  Start Date    End Date  \
# 52      Baytex Energy Corp.        Taxes  01-01-2016  12-31-2016
# 247  Eurasian Minerals Inc.         Fees  01-01-2016  12-31-2016
# 248  Eurasian Minerals Inc.         Fees  01-01-2016  12-31-2016
# 365   ROYAL DUTCH SHELL PLC         Fees  01-01-2016  12-31-2016
# 366   ROYAL DUTCH SHELL PLC         Fees  01-01-2016  12-31-2016
# 380    Rye Patch Gold Corp.         Fees  01-01-2016  12-31-2016
# 442                     NaN          NaN         NaN         NaN
# 443                     NaN          NaN         NaN         NaN
# 444                     NaN          NaN         NaN         NaN
#
#     Federal Government Tribal Governments State  Value (USD)  \
# 52                   N                NaN   NaN    4632565.0
# 247                  N                NaN   NaN      10799.0
# 248                NaN                NaN   NaN       1084.0
# 365                NaN                NaN   NaN     203100.0
# 366                NaN                NaN   NaN     243408.0
# 380                  N                NaN   NaN       3772.0
# 442                NaN                NaN   NaN          NaN
# 443                NaN                NaN   NaN          NaN
# 444                NaN                NaN   NaN          NaN
#
#                                                  Notes  \
# 52   Exchange rate from USD to CAD used in this rep...
# 247                              County recording fees
# 248                                        Filing fees
# 365                                                NaN
# 366                                                NaN
# 380  USD payments translated at 2016 annual average...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
#
#                                            Unnamed: 10 Government Type
# 52                                                 NaN         Unknown
# 247                                                NaN         Unknown
# 248                                                NaN         Unknown
# 365  There is a commissioner of the general land in...         Unknown
# 366  Again, most states have a division of oil and gas         Unknown
# 380                                                NaN         Unknown
# 442                                                NaN         Unknown
# 443                                                NaN         Unknown
# 444                                                NaN         Unknown

# %%
df = df.drop(df.index[442:445])

# %%
df = df[df["Value (USD)"] >= 0]

# %% [markdown]
# ## Prepare Source-Target-Value dataframe

# %%
links = pd.DataFrame(columns=['source','target','value'])

# %%
to_append = df.groupby(['Government Type'],as_index=False)['Value (USD)'].sum()
to_append["source"] = "Total"
to_append.rename(columns = {'Government Type':'target', 'Value (USD)' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['value'], ascending = False)
links = pd.concat([links,to_append])

print(to_append['value'].sum())
links
# Out:
# 2360235274.0
#   source   target         value
# 0  Total  Federal  1.326789e+09
# 1  Total    State  9.593532e+08
# 2  Total   Tribal  6.899835e+07
# 3  Total  Unknown  5.094728e+06

# %%
to_append = df.groupby(['Government Type','Payment Type'],as_index=False)['Value (USD)'].sum()
to_append.rename(columns = {'Government Type':'source','Payment Type':'target', 'Value (USD)' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['value'], ascending = False)
links = pd.concat([links,to_append])

print(to_append['value'].sum())
links
# Out:
# 2360235274.0
#      source                                    target         value
# 0     Total                                   Federal  1.326789e+09
# 1     Total                                     State  9.593532e+08
# 2     Total                                    Tribal  6.899835e+07
# 3     Total                                   Unknown  5.094728e+06
# 2   Federal                                 Royalties  7.944091e+08
# 8     State                                     Taxes  5.901037e+08
# 3   Federal                                     Taxes  4.096844e+08
# 7     State                                 Royalties  2.787502e+08
# 1   Federal                                      Fees  9.466987e+07
# 5     State                                      Fees  8.414347e+07
# 11   Tribal                   Production entitlements  3.195508e+07
# 0   Federal                                   Bonuses  2.802562e+07
# 12   Tribal                                 Royalties  2.210378e+07
# 13   Tribal                                     Taxes  7.431555e+06
# 4     State                                   Bonuses  6.265747e+06
# 10   Tribal                                      Fees  5.229382e+06
# 15  Unknown                                     Taxes  4.632565e+06
# 9    Tribal                                   Bonuses  2.278557e+06
# 14  Unknown                                      Fees  4.621630e+05
# 6     State  Payments for infrastructure improvements  9.000000e+04

# %%
to_append = df.groupby(['Payment Type','Reporting Company'],as_index=False)['Value (USD)'].sum()
to_append.rename(columns = {'Payment Type':'source','Reporting Company':'target', 'Value (USD)' : 'value'}, inplace = True)
to_append = to_append.sort_values(by=['value'], ascending = False)
links = pd.concat([links,to_append])

print(to_append['value'].sum())
links
# Out:
# 2360235274.0
#                                        source  \
# 0                                       Total
# 1                                       Total
# 2                                       Total
# 3                                       Total
# 2                                     Federal
# 8                                       State
# 3                                     Federal
# 7                                       State
# 1                                     Federal
# 5                                       State
# 11                                     Tribal
# 0                                     Federal
# 12                                     Tribal
# 13                                     Tribal
# 4                                       State
# 10                                     Tribal
# 15                                    Unknown
# 9                                      Tribal
# 14                                    Unknown
# 6                                       State
# 69                                  Royalties
# 81                                  Royalties
# 98                                      Taxes
# 90                                      Taxes
# 86                                      Taxes
# 89                                      Taxes
# 123                                     Taxes
# 52                                       Fees
# 53                                       Fees
# 76                                  Royalties
# ..                                        ...
# 45                                       Fees
# 51                                       Fees
# 33                                       Fees
# 0                          BNK Petroleum Inc.  1.103100e+04
# 105                 Freegold Ventures Limited  7.737000e+03
# 103                    Eurasian Minerals Inc.  4.209000e+03
# 12                         BNK Petroleum Inc.  3.824000e+03
# 102                         EntrA©e Gold Inc.  3.500000e+02
#
# [148 rows x 3 columns]

# %%
unique_list = pd.concat([links['source'], links['target']]).unique()
replace_dict = {k: v for v, k in enumerate(unique_list)}

# %%
links_replaced = links.replace({"source": replace_dict,"target": replace_dict})

# %%
links_replaced
# Out:
#      source  target         value
# 0         0       1  1.326789e+09
# 1         0       2  9.593532e+08
# 2         0       3  6.899835e+07
# 3         0       4  5.094728e+06
# 2         1       5  7.944091e+08
# 8         2       6  5.901037e+08
# 3         1       6  4.096844e+08
# 7         2       5  2.787502e+08
# 1         1       7  9.466987e+07
# 5         2       7  8.414347e+07
# 11        3       8  3.195508e+07
# 0         1       9  2.802562e+07
# 12        3       5  2.210378e+07
# 13        3       6  7.431555e+06
# 4         2       9  6.265747e+06
# 10        3       7  5.229382e+06
# 15        4       6  4.632565e+06
# 9         3       9  2.278557e+06
# 14        4       7  4.621630e+05
# 6         2      10  9.000000e+04
# 69        5      11  6.026200e+08
# 81        5      12  3.747777e+08
# 98        6      13  1.916800e+08
# 90        6      14  1.913385e+08
# 86        6      15  1.715860e+08
# 89        6      11  1.177172e+08
# 123       6      16  1.100046e+08
# 52        7      12  5.859035e+07
# 53        7      17  5.273256e+07
# 76        5      18  4.453751e+07
# ..      ...     ...           ...
# 45        7      61  2.338910e+05
# 51        7      62  2.160310e+05
# 33        7      26  2.126600e+05
# 60        7      63  2.000000e+05
# 48        7      29  1.886220e+05
# 9         7      64  1.811570e+05
# 32        7      65  1.810770e+05
# 88        6      66  1.765560e+05
# 108       6      67  1.600000e+05
# 29        7      68  1.508970e+05
# 59        7      69  1.295710e+05
# 40        7      70  1.282630e+05
# 109       6      71  1.207180e+05
# 35        7      23  1.207180e+05
# 55        7      42  1.143720e+05
# 36        7      71  1.131730e+05
# 65        7      72  1.058170e+05
# 20        7      73  1.056280e+05
# 28        7      52  9.808300e+04
# 57        7      74  9.808300e+04
# 122       6      74  9.808300e+04
# 3         9      18  9.053800e+04
# 66       10      51  9.000000e+04
# 30        7      75  8.867400e+04
# 124       6      69  4.002600e+04
# 0         9      66  1.103100e+04
# 105       6      75  7.737000e+03
# 103       6      49  4.209000e+03
# 12        7      66  3.824000e+03
# 102       6      56  3.500000e+02
#
# [148 rows x 3 columns]

# %%
nodes = pd.DataFrame(unique_list)
nodes.rename(columns = {0:'name'}, inplace = True)

# %%
nodes_json= pd.DataFrame(nodes).to_json(orient='records')
nodes_json
# Out:
# '[{"name":"Total"},{"name":"Federal"},{"name":"State"},{"name":"Tribal"},{"name":"Unknown"},{"name":"Royalties"},{"name":"Taxes"},{"name":"Fees"},{"name":"Production entitlements"},{"name":"Bonuses"},{"name":"Payments for infrastructure improvements"},{"name":"BP P.L.C."},{"name":"ROYAL DUTCH SHELL PLC"},{"name":"Encana Corporation"},{"name":"Barrick Gold Corporation"},{"name":"Agrium Inc."},{"name":"Teck Resources Limited"},{"name":"Rio Tinto PLC"},{"name":"Enerplus Corporation"},{"name":"Kinross Gold Corporation"},{"name":"CNOOC Limited"},{"name":"Potash Corporation of Saskatchewan Inc."},{"name":"Silver Standard Resources Inc."},{"name":"Graymont Limited"},{"name":"Coeur Mining, Inc."},{"name":"Baytex Energy Corp."},{"name":"Goldcorp Inc."},{"name":"Crescent Point Energy Corp."},{"name":"Capstone Mining Corp."},{"name":"PetroShale Inc."},{"name":"Energy Fuels Inc"},{"name":"Vermilion Energy Inc."},{"name":"Cameco Corporation"},{"name":"Votorantim Cement North America Inc."},{"name":"Klondex Mines Ltd."},{"name":"Enirgi Group Corporation"},{"name":"Ur-Energy Inc."},{"name":"New Gold Inc."},{"name":"Uranium One Inc."},{"name":"KGHM International"},{"name":"Eagle Energy Inc."},{"name":"Northern Dynasty Minerals Ltd."},{"name":"Scorpio Gold Corporation"},{"name":"McEwen Mining Inc."},{"name":"Golden Queen Mining Co. Ltd."},{"name":"Americas Silver Corporation"},{"name":"Source Energy Services US LP"},{"name":"OceanaGold Corporation"},{"name":"Agnico Eagle Mines Limited"},{"name":"Eurasian Minerals Inc."},{"name":"Liberty Gold Corp. (formerly Pilot Gold Inc.)"},{"name":"Midas Gold Corp"},{"name":"Excelsior Mining Corp"},{"name":"Rye Patch Gold Corp."},{"name":"Premier Gold Mines Limited"},{"name":"Prairie Provident Resources Inc."},{"name":"EntrA\\u00a9e Gold Inc."},{"name":"IC Potash Corp."},{"name":"Azarga Uranium Corp."},{"name":"Gold Standard Ventures Corp."},{"name":"Arizona Mining Inc."},{"name":"NewCastleGold Ltd"},{"name":"Quaterra Resources Inc."},{"name":"TriMetals Mining Inc."},{"name":"Anglo American plc"},{"name":"GoldMining Inc."},{"name":"BNK Petroleum Inc."},{"name":"Hudbay Minerals Inc."},{"name":"Franco-Nevada Corporation"},{"name":"TransAlta Corporation"},{"name":"LeadFX Inc."},{"name":"Imperial Metals Corporation"},{"name":"West Kirkland Mining Inc."},{"name":"Coral Gold Resources Ltd."},{"name":"Taseko Mines Limited"},{"name":"Freegold Ventures Limited"}]'

# %%
links_json= pd.DataFrame(links_replaced).to_json(orient='records')
links_json
# Out:
# '[{"source":0,"target":1,"value":1326789026.0},{"source":0,"target":2,"value":959353173.0},{"source":0,"target":3,"value":68998347.0},{"source":0,"target":4,"value":5094728.0},{"source":1,"target":5,"value":794409147.0},{"source":2,"target":6,"value":590103721.0},{"source":1,"target":6,"value":409684392.0},{"source":2,"target":5,"value":278750235.0},{"source":1,"target":7,"value":94669871.0},{"source":2,"target":7,"value":84143470.0},{"source":3,"target":8,"value":31955077.0},{"source":1,"target":9,"value":28025616.0},{"source":3,"target":5,"value":22103776.0},{"source":3,"target":6,"value":7431555.0},{"source":2,"target":9,"value":6265747.0},{"source":3,"target":7,"value":5229382.0},{"source":4,"target":6,"value":4632565.0},{"source":3,"target":9,"value":2278557.0},{"source":4,"target":7,"value":462163.0},{"source":2,"target":10,"value":90000.0},{"source":5,"target":11,"value":602620019.0},{"source":5,"target":12,"value":374777662.0